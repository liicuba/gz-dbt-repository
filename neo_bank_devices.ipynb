# %% [markdown]
# <a href="https://colab.research.google.com/github/liicuba/gz-dbt-repository/blob/main/neo_bank_devices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#installing google-cloud-bigquery libraries
# !pip install google-cloud-bigquery

# %%
#Import the library bigquery
from google.cloud import bigquery

#Creates a BigQuery client
client = bigquery.Client()

# %%
#google colab auth.
from google.colab import auth
#import pandas library
import pandas as pd

#authenticate the user to access Google Cloud resources
auth.authenticate_user()

# Define the SQL query to retrieve all data from the 'devices' table and specify the project ID
query = "SELECT * FROM `neo-bank-432422.neo_bank.devices`"
project = "neo-bank-432422"

# Use pandas to execute the SQL query and load the results into a Pandas DataFrame
# The `project_id` argument specifies the Google Cloud project
df_devices = pd.read_gbq(query=query, project_id=project)

# %%
df_devices.head()
# Out:
#   string_field_0 string_field_1
# 0          Apple      user_6809
# 1          Apple      user_3636
# 2          Apple       user_510
# 3          Apple      user_3468
# 4          Apple      user_7036

# %%
df_devices = pd.read_gbq(query=query, project_id=project)

# Renaming columns using the rename method
df_devices.rename(columns={'string_field_0': 'brand', 'string_field_1': 'user_id'},inplace=True)

df_devices.head()
# Out:
#    brand    user_id
# 0  Apple  user_6809
# 1  Apple  user_3636
# 2  Apple   user_510
# 3  Apple  user_3468
# 4  Apple  user_7036

# %%
#describe method
df_devices.describe()
# Out:
#           brand    user_id
# count     19431      19431
# unique        4      19431
# top     Android  user_6809
# freq       9714          1

# %%
# Check for missing values
print(df_devices.isnull().sum())
# Out:
# brand      0
# user_id    0
# dtype: int64

# %%
# Check for duplicates
print("Number of duplicates:",df_devices.duplicated().sum())
# Out:
# Number of duplicates: 0

# %%
df_devices.dtypes
# Out:
# brand      object
# user_id    object
# dtype: object

# %%
job_config = bigquery.LoadJobConfig(
    schema=[
        bigquery.SchemaField("brand", "STRING"),
        bigquery.SchemaField("user_id", "STRING"),

    ],
    write_disposition=bigquery.WriteDisposition.WRITE_TRUNCATE,  # Opcional: Truncar (resetar?) a tabela existente
)

client = bigquery.Client(project='neo-bank-432422')

table_ref = client.dataset('neo_bank').table('devices_clean')
load_job = client.load_table_from_dataframe(df_devices, table_ref, job_config=job_config)
load_job.result()
# Out:
# LoadJob<project=neo-bank-432422, location=EU, id=d64cf43b-79f5-4653-8e8a-a8762fa5ea49>

# %%
# Save the DataFrame as a CSV file
#df_devices.to_csv('devices_clean.csv', index=False)

#r: Indicates that the file will be opened for reading.
#b: Specifies that the file will be opened in binary mode.

#df_devices.head()
# Out:
#    brand    user_id
# 0  Apple  user_6809
# 1  Apple  user_3636
# 2  Apple   user_510
# 3  Apple  user_3468
# 4  Apple  user_7036
