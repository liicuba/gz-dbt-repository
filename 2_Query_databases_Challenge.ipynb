# %% [markdown]
# <a href="https://colab.research.google.com/github/liicuba/gz-dbt-repository/blob/main/2_Query_databases_Challenge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  ![Emil](data:image/png;base64,...)

# %% [markdown]
# # Querying databases

# %% [markdown]
# In this challenge, we will query data from two common forms of SQL databases - MySQL & BigQuery
#
# <u>Note:</u> Querying data directly from BigQuery to your notebooks will most likely be very useful during project weeks!

# %% [markdown]
# ## SQL database

# %% [markdown]
# Whenever a new deal is made, the Circle data pipeline automatically saves these to a MySQL database.
#
# We will load this data directly in the colab notebook and read them as pandas dataframes - we can then perform our analysis in Python!

# %% [markdown]
# Execute the cell below to install `pymsql` library. \
# This will allow you to interact with a MySQL database in Python

# %%
#!pip install pymysql --upgrade 'sqlalchemy<2.0'
# !pip install --upgrade sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.10/dist-packages (1.4.52)
# Collecting sqlalchemy
#   Using cached SQLAlchemy-2.0.31-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy) (3.0.3)
# Installing collected packages: sqlalchemy
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 1.4.52
#     Uninstalling SQLAlchemy-1.4.52:
#       Successfully uninstalled SQLAlchemy-1.4.52
# Successfully installed sqlalchemy-2.0.31

# %% [markdown]
# We will now use SQLAlchemy to create the connection. Please refer to the lecture slides for the correct imports / syntax.

# %% [markdown]
# *The connection settings below are what you will need to access the Circle databse*

# %% [markdown]
# - `driver_name` = "mysql+pymysql"
#
# - `db_host` = "db-mysql-ams3-59999-do-user-4791174-0.b.db.ondigitalocean.com"
#
# - `db_port` = 25060
# - `db_name` = "wagon_gwz"
# - `db_user`="wagon_gwz_readonly"
# - `db_pass`="MAiyXsbfH@JfxNDgZcxqUaMhrMNiG4TN"

# %%
# your code here

# Importing necessary components from SQLAlchemy
from sqlalchemy import inspect, create_engine, engine


# Define connection parameters for the MySQL database

driver_name = "mysql+pymysql"  # The driver used for MySQL with PyMySQL
db_host = "db-mysql-ams3-59999-do-user-4791174-0.b.db.ondigitalocean.com"  # Hostname of the MySQL database server
db_port = 25060  # Port number for the MySQL connection
db_name = "wagon_gwz"  # Name of the database to connect to
db_user = "wagon_gwz_readonly"  # Username for the database connection
db_pass = "MAiyXsbfH@JfxNDgZcxqUaMhrMNiG4TN"  # Password for the database connection


# Create a SQLAlchemy engine instance to connect to the database

con = create_engine(
   # Equivalent URL:
   # mysql+pymysql://<db_user>:<db_pass>@<db_host>:<db_port>/<db_name>
   engine.url.URL.create(
       drivername=driver_name,
       username=db_user,
       password=db_pass,
       host=db_host,
       port=db_port,
       database=db_name,
   )
)

# %% [markdown]
# Once you have established a connection, list all the tables in the database.

# %%
from sqlalchemy import inspect, create_engine, engine

# Define connection parameters
driver_name = "mysql+pymysql"
db_host = "db-mysql-ams3-59999-do-user-4791174-0.b.db.ondigitalocean.com"
db_port = 25060
db_name = "wagon_gwz"
db_user = "wagon_gwz_readonly"
db_pass = "MAiyXsbfH@JfxNDgZcxqUaMhrMNiG4TN"

# Create a SQLAlchemy engine instance to connect to the database

con = create_engine(
   # Equivalent URL:
   # mysql+pymysql://<db_user>:<db_pass>@<db_host>:<db_port>/<db_name>
   engine.url.URL.create(
       drivername=driver_name,
       username=db_user,
       password=db_pass,
       host=db_host,
       port=db_port,
       database=db_name,
   )
)

# Use SQLAlchemy's inspect function to get database schema information
inspector = inspect(con)

# List all table names in the database
tables = inspector.get_table_names()

# Print the list of table names
print("Tables in the database:")
for table in tables:
    print(table)
# Out:
# Tables in the database:
# acquisition
# deals
# deals_churn
# gz_low_margin
# gz_product
# gz_sales

# %% [markdown]
# Finally, load all the deals in a Pandas DataFrame.

# %%
# your code here

import pandas as pd

query = "select * from deals"

pd.read_sql (query, con)
# Out:
#     deal_id            deal_name        contact_email  \
# 0         1              Asana_1      asana@gmail.com
# 1         2           Bolsport_1   bolsport@gmail.com
# 2         3   CentreCommercial_1     centre@gmail.com
# 3         4              HIPPI_1      hippi@gmail.com
# 4         5               Jane_1       jane@gmail.com
# 5         6            McKinar_1    mckinar@gmail.com
# 6         7           Mutuelle_1   mutuelle@gmail.com
# 7         8          OffStudio_1        off@gmail.com
# 8         9            Peacock_1    peacock@gmail.com
# 9        10                Qee_1        qee@gmail.com
# 10       11                 R2_1         r2@gmail.com
# 11       12            Raffine_1    raffine@gmail.com
# 12       13             Satnam_1     satnam@gmail.com
# 13       14           Seinogra_1   seinogra@gmail.com
# 14       15             Silexa_1     silexa@gmail.com
# 15       16        StadeFrance_1      stade@gmail.com
# 16       17       TroisièmeSet_1  troisième@gmail.com
# 17       18  Yoga&PilateStudio_1       yoga@gmail.com
# 18       19           YogaLoft_1   yogaloft@gmail.com
# 19       21            london_da     london@gmail.com
#
#                          deal_owner        pipeline     deal_stage priority  \
# 0   olivier@donnees-transitions.com  Sales pipeline  contract_sent   Medium
# 1   olivier@donnees-transitions.com  Sales pipeline    closed_lost   Medium
# 2   olivier@donnees-transitions.com  Sales pipeline     To contact     High
# 3   olivier@donnees-transitions.com  Sales pipeline    closed_lost      Low
# 4   olivier@donnees-transitions.com  Sales pipeline     To contact   Medium
# 5   olivier@donnees-transitions.com  Sales pipeline  contract_sent     High
# 6   olivier@donnees-transitions.com  Sales pipeline     To contact      Low
# 7   olivier@donnees-transitions.com  Sales pipeline     To contact     High
# 8   olivier@donnees-transitions.com  Sales pipeline     To contact     High
# 9   olivier@donnees-transitions.com  Sales pipeline     closed_won     High
# 10  olivier@donnees-transitions.com  Sales pipeline     To contact     High
# 11  olivier@donnees-transitions.com  Sales pipeline     To contact     High
# 12  olivier@donnees-transitions.com  Sales pipeline     To contact     High
# 13  olivier@donnees-transitions.com  Sales pipeline     To contact     High
# 14  olivier@donnees-transitions.com  Sales pipeline     To contact      Low
# 15  olivier@donnees-transitions.com  Sales pipeline     To contact   Medium
# 16  olivier@donnees-transitions.com  Sales pipeline     To contact   Medium
# 17  olivier@donnees-transitions.com  Sales pipeline     To contact     High
# 18  olivier@donnees-transitions.com  Sales pipeline     To contact      Low
# 19                  oli@lewagon.org  Sales pipeline     To contact     High
#
#                    comment          last_event          updated_at
# 0          Yoga specialist   Last Remind 20/06 2022-12-05 21:47:35
# 1   Sport sales specialist                     2022-11-04 16:43:51
# 2                                           KO 2022-10-03 06:58:25
# 3                            Last Remind 02/05 2023-01-27 16:43:35
# 4            Concept store   Last Remind 30/08 2022-10-03 06:58:25
# 5        t-shirt for event                  Ok 2022-11-03 22:46:30
# 6                                           Ok 2022-10-03 06:58:25
# 7            Concept store   Last Remind 30/08 2022-10-03 06:58:25
# 8          Yoga specialist   Last Remind 30/08 2022-10-03 06:58:25
# 9          Yoga specialist   Last Remind 24/08 2022-10-03 07:21:21
# 10                                  Call 01.09 2022-10-03 06:58:25
# 11                           Last Remind 06/09 2022-10-03 06:58:25
# 12         Yoga specialist   Last Remind 20/06 2022-10-03 06:58:25
# 13         Yoga specialist    KO - not premium 2022-10-03 06:58:25
# 14                           Last Remind 24/08 2022-10-03 06:58:25
# 15       t-shirt for event  KO - not in budget 2022-10-03 06:58:25
# 16       t-shirt for event   Last Remind 15/09 2022-10-03 06:58:25
# 17         Yoga specialist   Last Remind 30/08 2022-10-03 06:58:25
# 18                           Last Remind 02/05 2022-10-03 06:58:25
# 19              Intresting          Call 01.31 2023-01-27 16:29:17

# %% [markdown]
# 🎉 Congrats! You have now loaded data from a SQL database into a Python notebook in a few lines of code.

# %% [markdown]
# ## Load data from BigQuery

# %% [markdown]
# 1) In your BigQuery console, create a new dataset called `course29`.
#
# Copy [this table](https://console.cloud.google.com/bigquery?ws=!1m20!1m4!1m3!1sdt-le-wagon!2sbquxjob_24727252_183d6296a5b!3sEU!1m4!4m3!1sdata-analytics-bootcamp-363212!2scourse30!3sgwz_orders!1m4!1m3!1sdata-analytics-bootcamp-363212!2sbquxjob_60c28a98_184a5ccde33!3sEU!1m4!4m3!1sdata-analytics-bootcamp-363212!2scourse29!3sgwz_orders_samples&authuser=2&project=data-analytics-bootcamp-363212) into it.

# %% [markdown]
# 2) Next, load the data into a DataFrame. Since you're using Google Colab, connecting to a service account isn't necessary.
# Rather than importing with `from google.oauth2 import service_account`, we'll authenticate directly by using the script provided below.

# %%
from google.colab import auth

# Will collect your credentials
auth.authenticate_user()

# %%
#install google-cloud-bigquery pandas lybaries
#!pip install google-cloud-bigquery pandas


#will take your credentials
auth.authenticate_user()

#query bigquery
query = "select * from rich-synapse-420214.course29.gwz_orders_samples"

df = pd.read_gbq (query, project_id= "rich-synapse-420214")

#called the dataframe
df
# Out:
#        date_date  orders_id  customers_id country department  total_quantity  \
# 0     2021-07-12     932839        176738  FRANCE         17             275
# 1     2020-12-31     715121         29041  FRANCE         01              34
# 2     2020-06-26     494935        130040  FRANCE         01              34
# 3     2020-06-26     494928        130040  FRANCE         01              34
# 4     2020-10-26     627943         30714  FRANCE         01              34
# ...          ...        ...           ...     ...        ...             ...
# 4995  2020-08-28     559828        121046  FRANCE         29             202
# 4996  2019-06-18     137506          2615  FRANCE         84             205
# 4997  2021-12-16    1081749        225653  FRANCE         03             238
# 4998  2019-01-22      18507          2615  FRANCE         76             243
# 4999  2020-03-13     380657        111139  FRANCE         06             244
#
#       total_turnover
# 0            1014.00
# 1             172.80
# 2              94.77
# 3              94.62
# 4             123.25
# ...              ...
# 4995          589.96
# 4996          538.79
# 4997          814.86
# 4998          457.78
# 4999         1319.31
#
# [5000 rows x 7 columns]
